# %% [markdown]
# ### Kütüphaneleri İçeri Aktarma

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
from DataMacpy import *
# Out:
# DataMacpy Setup

# %% [markdown]
# ### Veriyi Ön İşleme

# %%
# Veriyi içeri aktaralım.

# veri yolumuzu verelim
file_path = 'pokemon.csv'

# verimizi okuyoruz. 
pokemon_data = pd.read_csv(file_path)

print("Setup Complete")
# Out:
# Setup Complete

# %%
import seaborn as sns
sns.heatmap(pokemon_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot: >

# %%
# Veri Görselleştirme

pokemon_data.tail(5)
# Out:
#      Number       Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 716     717    Yveltal     Dark  Flying    680  126     131       95     131
# 717     718    Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719    Diancie     Rock   Fairy    600   50     100      150     100
# 719     720      Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721  Volcanion     Fire   Water    600   80     110      120     130
#
#      Sp_Def  ...   Color  hasGender  Pr_Male   Egg_Group_1  Egg_Group_2  \
# 716      98  ...     Red      False      NaN  Undiscovered          NaN
# 717      95  ...   Green      False      NaN  Undiscovered          NaN
# 718     150  ...    Pink      False      NaN  Undiscovered          NaN
# 719     130  ...  Purple      False      NaN  Undiscovered          NaN
# 720      90  ...   Brown      False      NaN  Undiscovered          NaN
#
#      hasMegaEvolution Height_m Weight_kg  Catch_Rate       Body_Style
# 716             False     5.79     203.0          45        two_wings
# 717             False     5.00     305.0           3  serpentine_body
# 718              True     0.71       8.8           3        head_arms
# 719             False     0.51       9.0           3        head_only
# 720             False     1.70     195.0           3        quadruped
#
# [5 rows x 23 columns]

# %%
# hedef kolonumuzu belirleyelim.
y_not_enc = pokemon_data.Type_1
y_not_enc
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3         Fire
# 4         Fire
#         ...
# 716       Dark
# 717     Dragon
# 718       Rock
# 719    Psychic
# 720       Fire
# Name: Type_1, Length: 721, dtype: object

# %%
# target verilerimiz string olduğu için LabelEncoder yapıyoruz. Her sınıfı bir sayıya atıyoruz.
l_fit = LabelEncoder().fit(y_not_enc)
y = l_fit.transform(y_not_enc)
#y = pd.DataFrame(y, columns = ["Type_1"]) # dataframe'e çevirmek için bu satırı kullanabiliriz.
y[0:20]
# Out:
# array([ 9,  9,  9,  6,  6,  6, 17, 17, 17,  0,  0,  0,  0,  0,  0, 12, 12,
#        12, 12, 12])

# %%
# labellerimizi buluyoruz.
y_label = l_fit.inverse_transform([i for i in range(max(y)+1)])
label_and_num = list(zip(y_label, [i for i in range(max(y)+1)]))
label_and_num
# Out:
# [('Bug', 0),
#  ('Dark', 1),
#  ('Dragon', 2),
#  ('Electric', 3),
#  ('Fairy', 4),
#  ('Fighting', 5),
#  ('Fire', 6),
#  ('Flying', 7),
#  ('Ghost', 8),
#  ('Grass', 9),
#  ('Ground', 10),
#  ('Ice', 11),
#  ('Normal', 12),
#  ('Poison', 13),
#  ('Psychic', 14),
#  ('Rock', 15),
#  ('Steel', 16),
#  ('Water', 17)]

# %%
# özniteliklerimizi belirleyelim.
X = pokemon_data
X.drop(["Number", "Type_1"], axis=1, inplace=True) # tüm verilerimizden hedef kolonumuzu çıkarıyoruz.
# Number kolonumuzu da gereksiz olduğu eğitimde gereksiz olduğu için çıkarıyoruz.
X
# Out:
#            Name  Type_2  Total   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  \
# 0     Bulbasaur  Poison    318   45      49       49      65      65     45
# 1       Ivysaur  Poison    405   60      62       63      80      80     60
# 2      Venusaur  Poison    525   80      82       83     100     100     80
# 3    Charmander     NaN    309   39      52       43      60      50     65
# 4    Charmeleon     NaN    405   58      64       58      80      65     80
# ..          ...     ...    ...  ...     ...      ...     ...     ...    ...
# 716     Yveltal  Flying    680  126     131       95     131      98     99
# 717     Zygarde  Ground    600  108     100      121      81      95     95
# 718     Diancie   Fairy    600   50     100      150     100     150     50
# 719       Hoopa   Ghost    600   80     110       60     150     130     70
# 720   Volcanion   Water    600   80     110      120     130      90     70
#
#      Generation  ...   Color hasGender  Pr_Male   Egg_Group_1 Egg_Group_2  \
# 0             1  ...   Green      True    0.875       Monster       Grass
# 1             1  ...   Green      True    0.875       Monster       Grass
# 2             1  ...   Green      True    0.875       Monster       Grass
# 3             1  ...     Red      True    0.875       Monster      Dragon
# 4             1  ...     Red      True    0.875       Monster      Dragon
# ..          ...  ...     ...       ...      ...           ...         ...
# 716           6  ...     Red     False      NaN  Undiscovered         NaN
# 717           6  ...   Green     False      NaN  Undiscovered         NaN
# 718           6  ...    Pink     False      NaN  Undiscovered         NaN
# 719           6  ...  Purple     False      NaN  Undiscovered         NaN
# 720           6  ...   Brown     False      NaN  Undiscovered         NaN
#
#     hasMegaEvolution  Height_m  Weight_kg  Catch_Rate       Body_Style
# 0              False      0.71        6.9          45        quadruped
# 1              False      0.99       13.0          45        quadruped
# 2               True      2.01      100.0          45        quadruped
# 3              False      0.61        8.5          45   bipedal_tailed
# 4              False      1.09       19.0          45   bipedal_tailed
# ..               ...       ...        ...         ...              ...
# 716            False      5.79      203.0          45        two_wings
# 717            False      5.00      305.0           3  serpentine_body
# 718             True      0.71        8.8           3        head_arms
# 719            False      0.51        9.0           3        head_only
# 720            False      1.70      195.0           3        quadruped
#
# [721 rows x 21 columns]

# %%
# DataMacpy kütüphanemizdeki fonksiyon ile eksik veriye sahip kolonları buluyoruz.
cols_with_missing = find_missing_cols(X)
cols_with_missing
# Out:
# ['Type_2', 'Pr_Male', 'Egg_Group_2']

# %%
# Eksik bilgileri düşürüyoruz.
print(f"Eksik veriler düşürülmeden önce verilerimizin boyutu: {X.shape}")
X.drop(cols_with_missing, axis=1, inplace=True)
print(f"Eksik veriler düşürüldükten sonra verilerimizin boyutu: {X.shape}")
# Out:
# Eksik veriler düşürülmeden önce verilerimizin boyutu: (721, 21)
# Eksik veriler düşürüldükten sonra verilerimizin boyutu: (721, 18)

# %%
# DataMacpy kütüphanemizdeki fonksiyon ile benzersiz birimi 15'den fazla olan veri tipi object içeren kolonları buluyoruz.
object_cols, d = calc_object_cols(X, 15)
print(f"object_cols: {object_cols}\n\n d: {d}")

# Bu kolonları düşürüyoruz çünkü her veriye özel bir benzersiz bilgi içeriyorsa overfitting olabilir.
# Eğer dönüştürmeye kalkarsak her benzersiz birim için OneHotEncoder yaparsak çok fazla kolona sahip veri seti elde ederiz.
X = X.drop(object_cols, axis = 1)
X
# Out:
# object_cols: ['Name']
#
#  d: {'Name': 721}
#      Total   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  \
# 0      318   45      49       49      65      65     45           1
# 1      405   60      62       63      80      80     60           1
# 2      525   80      82       83     100     100     80           1
# 3      309   39      52       43      60      50     65           1
# 4      405   58      64       58      80      65     80           1
# ..     ...  ...     ...      ...     ...     ...    ...         ...
# 716    680  126     131       95     131      98     99           6
# 717    600  108     100      121      81      95     95           6
# 718    600   50     100      150     100     150     50           6
# 719    600   80     110       60     150     130     70           6
# 720    600   80     110      120     130      90     70           6
#
#      isLegendary   Color  hasGender   Egg_Group_1  hasMegaEvolution  Height_m  \
# 0          False   Green       True       Monster             False      0.71
# 1          False   Green       True       Monster             False      0.99
# 2          False   Green       True       Monster              True      2.01
# 3          False     Red       True       Monster             False      0.61
# 4          False     Red       True       Monster             False      1.09
# ..           ...     ...        ...           ...               ...       ...
# 716         True     Red      False  Undiscovered             False      5.79
# 717         True   Green      False  Undiscovered             False      5.00
# 718         True    Pink      False  Undiscovered              True      0.71
# 719         True  Purple      False  Undiscovered             False      0.51
# 720         True   Brown      False  Undiscovered             False      1.70
#
#      Weight_kg  Catch_Rate       Body_Style
# 0          6.9          45        quadruped
# 1         13.0          45        quadruped
# 2        100.0          45        quadruped
# 3          8.5          45   bipedal_tailed
# 4         19.0          45   bipedal_tailed
# ..         ...         ...              ...
# 716      203.0          45        two_wings
# 717      305.0           3  serpentine_body
# 718        8.8           3        head_arms
# 719        9.0           3        head_only
# 720      195.0           3        quadruped
#
# [721 rows x 17 columns]

# %%
# DataMacpy kütüphanemizdeki fonksiyon ile benzersiz birimi 0'dan fazla olan veri tipi object içeren
# kolonları buluyoruz.
object_cols, d = calc_object_cols(X, 0)
print(f"object_cols: {object_cols}\n\n d: {d}")
# Out:
# object_cols: ['Color', 'Egg_Group_1', 'Body_Style']
#
#  d: {'Color': 10, 'Egg_Group_1': 15, 'Body_Style': 14}

# %%
# Verilerimize OrdinalEncoder uyguluyoruz. OneHot denemesi yapılacak!
ordinal_encoder = OrdinalEncoder()
X[object_cols] = ordinal_encoder.fit_transform(X[object_cols])
X
# Out:
#      Total   HP  Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  \
# 0      318   45      49       49      65      65     45           1
# 1      405   60      62       63      80      80     60           1
# 2      525   80      82       83     100     100     80           1
# 3      309   39      52       43      60      50     65           1
# 4      405   58      64       58      80      65     80           1
# ..     ...  ...     ...      ...     ...     ...    ...         ...
# 716    680  126     131       95     131      98     99           6
# 717    600  108     100      121      81      95     95           6
# 718    600   50     100      150     100     150     50           6
# 719    600   80     110       60     150     130     70           6
# 720    600   80     110      120     130      90     70           6
#
#      isLegendary  Color  hasGender  Egg_Group_1  hasMegaEvolution  Height_m  \
# 0          False    3.0       True         10.0             False      0.71
# 1          False    3.0       True         10.0             False      0.99
# 2          False    3.0       True         10.0              True      2.01
# 3          False    7.0       True         10.0             False      0.61
# 4          False    7.0       True         10.0             False      1.09
# ..           ...    ...        ...          ...               ...       ...
# 716         True    7.0      False         11.0             False      5.79
# 717         True    3.0      False         11.0             False      5.00
# 718         True    5.0      False         11.0              True      0.71
# 719         True    6.0      False         11.0             False      0.51
# 720         True    2.0      False         11.0             False      1.70
#
#      Weight_kg  Catch_Rate  Body_Style
# 0          6.9          45         9.0
# 1         13.0          45         9.0
# 2        100.0          45         9.0
# 3          8.5          45         0.0
# 4         19.0          45         0.0
# ..         ...         ...         ...
# 716      203.0          45        12.0
# 717      305.0           3        10.0
# 718        8.8           3         3.0
# 719        9.0           3         6.0
# 720      195.0           3         9.0
#
# [721 rows x 17 columns]

# %%
# Verilerimizi train ve validation olarak ayırıyoruz.
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# ### Default değerler için Model seçimi yapıyoruz

# %% [markdown]
# #### Modelleri kütüphaneden içeri aktaralım.

# %%
from sklearn.svm import SVC

from sklearn.linear_model import SGDClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import ExtraTreesClassifier

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.ensemble import HistGradientBoostingClassifier

from sklearn.linear_model import LogisticRegression

from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import RandomForestClassifier, VotingClassifier

from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.ensemble import ExtraTreesClassifier

model_fit_and_predict(ExtraTreesClassifier(n_estimators=100, random_state=0), y_label, X_train, y_train, X_valid, y_valid)
# Out:
#  Toplam Doğruluk: % 45.39671098881625
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8AF4AEB0>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.222222    9     2      7  Fighting
# 2     Dragon          0.750000    4     3      1    Dragon
# 3   Electric          0.428571    7     3      4  Electric
# 4      Fairy          0.333333    3     1      2     Fairy
# 5   Fighting          0.200000    5     1      4    Normal
# 6       Fire          0.636364   11     7      4      Fire
# 7     Flying          0.000000    1     0      1      Fire
# 8      Ghost          0.666667    3     2      1     Ghost
# 9      Grass          0.923077   13    12      1     Grass
# 10    Ground          0.111111    9     1      8    Normal
# 11       Ice          0.000000    3     0      3     Grass
# 12    Normal          0.526316   19    10      9    Normal
# 13    Poison          0.333333    3     1      2  Fighting
# 14   Psychic          0.500000    8     4      4   Psychic
# 15      Rock          0.375000    8     3      5      Rock
# 16     Steel          0.428571    7     3      4     Steel
# 17     Water          0.736842   19    14      5     Water

# %%
clf1 = LogisticRegression(multi_class='multinomial', random_state=1)
clf2 = RandomForestClassifier(n_estimators=50, random_state=1)
clf3 = GaussianNB()
clf4 = DecisionTreeClassifier()

eclf1 = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('dtc', clf4)], voting='hard', verbose=True)

model_fit_and_predict(eclf1, y_label, X_train, y_train, X_valid, y_valid)
# Out:
# [Voting] ....................... (1 of 3) Processing lr, total=   0.1s
# [Voting] ....................... (2 of 3) Processing rf, total=   0.2s
# [Voting] ...................... (3 of 3) Processing dtc, total=   0.0s
#  Toplam Doğruluk: % 38.116522041960636
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8DB667F0>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.444444    9     4      5      Dark
# 2     Dragon          0.750000    4     3      1    Dragon
# 3   Electric          0.285714    7     2      5  Electric
# 4      Fairy          0.666667    3     2      1     Fairy
# 5   Fighting          0.400000    5     2      3    Dragon
# 6       Fire          0.727273   11     8      3      Fire
# 7     Flying          0.000000    1     0      1  Fighting
# 8      Ghost          0.333333    3     1      2       Bug
# 9      Grass          0.615385   13     8      5     Grass
# 10    Ground          0.000000    9     0      9  Fighting
# 11       Ice          0.000000    3     0      3  Electric
# 12    Normal          0.526316   19    10      9    Normal
# 13    Poison          0.000000    3     0      3  Electric
# 14   Psychic          0.250000    8     2      6   Psychic
# 15      Rock          0.125000    8     1      7    Dragon
# 16     Steel          0.000000    7     0      7     Grass
# 17     Water          0.736842   19    14      5     Water

# %%
# GridSearch ile 8 iterasyon sonucu ortaya çıkan
model_fit_and_predict(RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
                          criterion='gini', max_depth=450,
                          max_features=None, max_leaf_nodes=1500,
                          min_impurity_decrease=0.0,
                          min_samples_leaf=1, min_samples_split=3,
                          min_weight_fraction_leaf=0.0,
                          n_estimators=200), y_label, X_train, y_train, X_valid, y_valid)
# Out:
#  Toplam Doğruluk: % 37.58640888026853
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8D8E9040>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.111111    9     1      8  Fighting
# 2     Dragon          0.250000    4     1      3    Dragon
# 3   Electric          0.285714    7     2      5  Electric
# 4      Fairy          0.666667    3     2      1     Fairy
# 5   Fighting          0.200000    5     1      4    Normal
# 6       Fire          0.636364   11     7      4      Fire
# 7     Flying          0.000000    1     0      1    Poison
# 8      Ghost          0.666667    3     2      1     Ghost
# 9      Grass          0.615385   13     8      5     Grass
# 10    Ground          0.000000    9     0      9    Normal
# 11       Ice          0.000000    3     0      3  Electric
# 12    Normal          0.526316   19    10      9    Normal
# 13    Poison          0.000000    3     0      3  Electric
# 14   Psychic          0.500000    8     4      4   Psychic
# 15      Rock          0.375000    8     3      5      Rock
# 16     Steel          0.142857    7     1      6     Grass
# 17     Water          0.789474   19    15      4     Water

# %%
model_fit_and_predict(RandomForestClassifier(), y_label, X_train, y_train, X_valid, y_valid)
# Out:
#  Toplam Doğruluk: % 35.17818925713663
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8DF4FD60>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.000000    9     0      9  Fighting
# 2     Dragon          0.250000    4     1      3    Dragon
# 3   Electric          0.428571    7     3      4  Electric
# 4      Fairy          0.333333    3     1      2  Electric
# 5   Fighting          0.200000    5     1      4  Fighting
# 6       Fire          0.636364   11     7      4      Fire
# 7     Flying          0.000000    1     0      1      Fire
# 8      Ghost          0.666667    3     2      1     Ghost
# 9      Grass          0.615385   13     8      5     Grass
# 10    Ground          0.000000    9     0      9    Normal
# 11       Ice          0.000000    3     0      3  Electric
# 12    Normal          0.526316   19    10      9    Normal
# 13    Poison          0.333333    3     1      2  Fighting
# 14   Psychic          0.250000    8     2      6   Psychic
# 15      Rock          0.250000    8     2      6     Grass
# 16     Steel          0.000000    7     0      7     Grass
# 17     Water          0.842105   19    16      3     Water

# %%
model_fit_and_predict(ExtraTreesClassifier(bootstrap=True, ccp_alpha=0.0,
                          criterion='gini', max_depth=650,
                          max_features=None, max_leaf_nodes=1000,
                          min_impurity_decrease=0.0,
                          min_samples_leaf=1, min_samples_split=3,
                          min_weight_fraction_leaf=0.0,
                          n_estimators=100), y_label, X_train, y_train, X_valid, y_valid)
# Out:
#  Toplam Doğruluk: % 46.463297910666334
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8E2C6C70>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.222222    9     2      7      Dark
# 2     Dragon          0.750000    4     3      1    Dragon
# 3   Electric          0.285714    7     2      5      Dark
# 4      Fairy          0.333333    3     1      2     Fairy
# 5   Fighting          0.200000    5     1      4    Normal
# 6       Fire          0.545455   11     6      5      Fire
# 7     Flying          0.000000    1     0      1      Fire
# 8      Ghost          0.666667    3     2      1     Ghost
# 9      Grass          0.923077   13    12      1     Grass
# 10    Ground          0.111111    9     1      8    Normal
# 11       Ice          0.000000    3     0      3     Grass
# 12    Normal          0.578947   19    11      8    Normal
# 13    Poison          0.333333    3     1      2  Fighting
# 14   Psychic          0.500000    8     4      4   Psychic
# 15      Rock          0.500000    8     4      4      Rock
# 16     Steel          0.571429    7     4      3     Steel
# 17     Water          0.842105   19    16      3     Water

# %%
model_fit_and_predict(ExtraTreesClassifier(), y_label, X_train, y_train, X_valid, y_valid)
# Out:
#  Toplam Doğruluk: % 44.239790424000944
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x000001EC8D9B89A0>
#        label  TruePredsPercent  Sum  true  false most_frec
# 0        Bug          1.000000   13    13      0       Bug
# 1       Dark          0.222222    9     2      7      Dark
# 2     Dragon          1.000000    4     4      0    Dragon
# 3   Electric          0.285714    7     2      5      Dark
# 4      Fairy          0.333333    3     1      2     Fairy
# 5   Fighting          0.200000    5     1      4    Normal
# 6       Fire          0.545455   11     6      5      Fire
# 7     Flying          0.000000    1     0      1      Fire
# 8      Ghost          0.666667    3     2      1     Ghost
# 9      Grass          0.846154   13    11      2     Grass
# 10    Ground          0.111111    9     1      8    Normal
# 11       Ice          0.000000    3     0      3     Grass
# 12    Normal          0.684211   19    13      6    Normal
# 13    Poison          0.333333    3     1      2  Fighting
# 14   Psychic          0.375000    8     3      5   Psychic
# 15      Rock          0.375000    8     3      5     Grass
# 16     Steel          0.142857    7     1      6      Rock
# 17     Water          0.842105   19    16      3     Water
